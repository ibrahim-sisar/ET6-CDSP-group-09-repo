# %% [markdown]
# ## COVID-19 Mortality Data (2020)
#
# To explore the potential long-term health impacts of air pollution, we use IHME estimates of COVID-19 mortality for 2020
#
# ---

# %% [markdown]
# ### 📦 Import Required Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ### 📁 loading the dataset
#
# from the CSV raw file, and making a copy for the cleaned to be dataset
# and preview the first few rows.

# %%
raw_data = pd.read_csv("../1_datasets/raw_datasets/covid_deaths.csv")
cleaned_death_data = raw_data.copy()
cleaned_death_data.head()
# Out:
#   measure location   sex          age     cause   metric  year         val  \
# 0  Deaths    Spain  Both     All ages  COVID-19  Percent  2020    0.125091
# 1  Deaths    Spain  Both     All ages  COVID-19     Rate  2020  132.948639
# 2  Deaths    Spain  Both  15-49 years  COVID-19  Percent  2020    0.148088
# 3  Deaths    Spain  Both  15-49 years  COVID-19     Rate  2020   10.472981
# 4  Deaths     Fiji  Both     All ages  COVID-19  Percent  2021    0.121380
#
#         upper       lower
# 0    0.130679    0.118814
# 1  139.131075  126.395299
# 2    0.156547    0.139678
# 3   11.087217    9.876074
# 4    0.234511    0.063697

# %% [markdown]
# ### 🧾 Initial Column Inspection
# We inspect:
# - Full list of column names
# - Identify metadata columns
# - Identify unnecessary columns

# %%
cleaned_death_data.columns
# Out:
# Index(['measure', 'location', 'sex', 'age', 'cause', 'metric', 'year', 'val',
#        'upper', 'lower'],
#       dtype='object')

# %%
# checking initial rows and columns number
cleaned_death_data.shape
# Out:
# (200, 10)

# %% [markdown]
# ### 🔍 Summary Statistics & Missing Data
#
# - Check `.info()` for data types and nulls
# - Use `.isnull().sum()` to count missing values

# %%
cleaned_death_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   measure   200 non-null    object
#  1   location  200 non-null    object
#  2   sex       200 non-null    object
#  3   age       200 non-null    object
#  4   cause     200 non-null    object
#  5   metric    200 non-null    object
#  6   year      200 non-null    int64
#  7   val       200 non-null    float64
#  8   upper     200 non-null    float64
#  9   lower     200 non-null    float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 15.8+ KB

# %%
cleaned_death_data.isnull().sum()
# Out:
# measure     0
# location    0
# sex         0
# age         0
# cause       0
# metric      0
# year        0
# val         0
# upper       0
# lower       0
# dtype: int64

# %% [markdown]
# ### 🧹 Column Renaming and Dropping
# Drop columns:
# - Drop columns not needed for analysis
#
# Rename columns:
# - Standardize names

# %%
cleaned_death_data = cleaned_death_data.drop(
    ["sex", "measure", "cause"], axis=1, errors="ignore"
)
cleaned_death_data = cleaned_death_data.rename(
    columns={"val": "COVID Deaths Val", "location": "Country"}
)
cleaned_death_data.head()
# Out:
#   Country          age   metric  year  COVID Deaths Val       upper  \
# 0   Spain     All ages  Percent  2020          0.125091    0.130679
# 1   Spain     All ages     Rate  2020        132.948639  139.131075
# 2   Spain  15-49 years  Percent  2020          0.148088    0.156547
# 3   Spain  15-49 years     Rate  2020         10.472981   11.087217
# 4    Fiji     All ages  Percent  2021          0.121380    0.234511
#
#         lower
# 0    0.118814
# 1  126.395299
# 2    0.139678
# 3    9.876074
# 4    0.063697

# %% [markdown]
# ### 🎯 Filtering by Country
#
# To ensure data consistency and focus our analysis on relevant entries, we applied filters using the `isin()` method

# %%
countries_to_keep = [
    "Egypt",
    "India",
    "United States of America",
    "Chile",
    "Nigeria",
    "Italy",
    "China",
    "Japan",
    "Afghanistan",
    "Germany",
    "Russian Federation",
    "Spain",
    "Romania",
    "Indonesia",
    "Saudi Arabia",
    "Bangladesh",
    "Republic of Korea",
    "South Africa",
    "Ethiopia",
    "Kenya",
    "Brazil",
    "Mexico",
    "Canada",
    "Australia",
    "Fiji",
]

cleaned_death_data = cleaned_death_data[
    cleaned_death_data["Country"].isin(countries_to_keep)
]
cleaned_death_data.head(26)
# Out:
#       Country          age   metric  year  COVID Deaths Val       upper  \
# 0       Spain     All ages  Percent  2020          0.125091    0.130679
# 1       Spain     All ages     Rate  2020        132.948639  139.131075
# 2       Spain  15-49 years  Percent  2020          0.148088    0.156547
# 3       Spain  15-49 years     Rate  2020         10.472981   11.087217
# 4        Fiji     All ages  Percent  2021          0.121380    0.234511
# 5        Fiji     All ages     Rate  2021        124.301052  246.763477
# 6        Fiji  15-49 years  Percent  2021          0.123064    0.236029
# 7        Fiji  15-49 years     Rate  2021         38.868283   77.220136
# 8   Indonesia     All ages  Percent  2020          0.046378    0.091085
# 9   Indonesia     All ages     Rate  2020         32.667317   67.054381
# 10  Indonesia  15-49 years  Percent  2020          0.049906    0.096787
# 11  Indonesia  15-49 years     Rate  2020         10.159491   20.825411
# 12      China     All ages  Percent  2021          0.000092    0.000332
# 13      China     All ages     Rate  2021          0.074704    0.282800
# 14      China  15-49 years  Percent  2021          0.000047    0.000163
# 15      China  15-49 years     Rate  2021          0.005552    0.020053
# 16  Australia     All ages  Percent  2021          0.019511    0.022927
# 17  Australia     All ages     Rate  2021         13.253704   15.534149
# 18  Australia  15-49 years  Percent  2021          0.017440    0.020472
# 19  Australia  15-49 years     Rate  2021          1.430555    1.676678
# 20      Spain     All ages  Percent  2021          0.087743    0.090865
# 21      Spain     All ages     Rate  2021         85.816866   88.698227
# 22      Spain  15-49 years  Percent  2021          0.124455    0.130048
# 23      Spain  15-49 years     Rate  2021          8.807386    9.211047
# 24     Mexico     All ages  Percent  2020          0.251190    0.301093
# 25     Mexico     All ages     Rate  2020        212.122870  254.596607
#
#          lower
# 0     0.118814
# 1   126.395299
# 2     0.139678
# 3     9.876074
# 4     0.063697
# 5    75.311090
# 6     0.064148
# 7    23.558042
# 8     0.015115
# 9    10.621372
# 10    0.016150
# 11    3.318329
# 12    0.000007
# 13    0.006005
# 14    0.000004
# 15    0.000437
# 16    0.015796
# 17   10.739787
# 18    0.014142
# 19    1.159229
# 20    0.084108
# 21   82.584882
# 22    0.118479
# 23    8.408361
# 24    0.204565
# 25  172.992768

# %% [markdown]
# ### Filter data for Rate metric, year 2020, and age 15–49 years
#
# We keep only rows where:
# - `metric` = **"Rate"**
# - `year` = **2020**
# - `age` = **"15–49 years"**
#
# This focuses the analysis on younger adults, to explore if factors like PM2.5 exposure explain higher COVID-19 mortality beyond age-related vulnerability.

# %%
df_cleaned_death_data = cleaned_death_data[
    (cleaned_death_data["metric"] == "Rate")
    & (cleaned_death_data["year"] == 2020)
    & (cleaned_death_data["age"] == "15-49 years")
]
print(df_cleaned_death_data)
# Out:
#                       Country          age metric  year  COVID Deaths Val  \
# 3                       Spain  15-49 years   Rate  2020         10.472981
# 11                  Indonesia  15-49 years   Rate  2020         10.159491
# 27                     Mexico  15-49 years   Rate  2020         57.019696
# 31         Russian Federation  15-49 years   Rate  2020         18.195048
# 35                      Chile  15-49 years   Rate  2020         17.427140
# 39                Afghanistan  15-49 years   Rate  2020         67.643147
# 43               South Africa  15-49 years   Rate  2020         54.933363
# 47                 Bangladesh  15-49 years   Rate  2020         18.638962
# 59                     Canada  15-49 years   Rate  2020         11.392234
# 63                      India  15-49 years   Rate  2020         18.618172
# 71          Republic of Korea  15-49 years   Rate  2020          0.239668
# 79                   Ethiopia  15-49 years   Rate  2020         24.108446
# 83                    Nigeria  15-49 years   Rate  2020         18.018582
# 87                       Fiji  15-49 years   Rate  2020          2.641567
# 99                    Germany  15-49 years   Rate  2020          3.468349
# 111  United States of America  15-49 years   Rate  2020         33.359688
# 115                     Kenya  15-49 years   Rate  2020         42.762396
# 119                     Japan  15-49 years   Rate  2020          0.189647
# 139                 Australia  15-49 years   Rate  2020          0.231634
# 143                    Brazil  15-49 years   Rate  2020         21.901328
# 151                   Romania  15-49 years   Rate  2020         18.023526
# 163                     Italy  15-49 years   Rate  2020          8.201799
# 175              Saudi Arabia  15-49 years   Rate  2020         17.390042
# 183                     China  15-49 years   Rate  2020          0.306865
# 199                     Egypt  15-49 years   Rate  2020         26.043847
#
#          upper      lower
# 3    11.087217   9.876074
# 11   20.825411   3.318329
# 27   70.946973  44.181729
# 31   22.069367  14.809403
# 35   18.275500  16.582775
# 39   90.454679  51.068891
# 43   54.955219  54.898359
# 47   25.122020  15.987977
# 59   12.087162  10.701911
# 63   19.671096  17.520649
# 71    0.378687   0.155330
# 79   26.069180  22.386505
# 83   19.728042  16.611754
# 87    5.517765   0.654506
# 99    3.876612   3.187289
# 111  34.663460  32.058489
# 115  46.483915  39.448608
# 119   0.211685   0.170640
# 139   0.243760   0.217310
# 143  23.845813  20.234796
# 151  26.292571  10.591084
# 163   8.677592   7.719720
# 175  20.610325  13.677623
# 183   1.600954   0.069869
# 199  34.426903  17.968110

# %% [markdown]
# Rename columns:
# - Standardize names

# %%
df_cleaned_death_data = df_cleaned_death_data.rename(
    columns={"year": "Year", "COVID Deaths Val": "COVID Deaths Val (Rate)"},
)

# %%
df_cleaned_death_data.reset_index(drop=True)
# Out:
#                      Country          age metric  Year  \
# 0                      Spain  15-49 years   Rate  2020
# 1                  Indonesia  15-49 years   Rate  2020
# 2                     Mexico  15-49 years   Rate  2020
# 3         Russian Federation  15-49 years   Rate  2020
# 4                      Chile  15-49 years   Rate  2020
# 5                Afghanistan  15-49 years   Rate  2020
# 6               South Africa  15-49 years   Rate  2020
# 7                 Bangladesh  15-49 years   Rate  2020
# 8                     Canada  15-49 years   Rate  2020
# 9                      India  15-49 years   Rate  2020
# 10         Republic of Korea  15-49 years   Rate  2020
# 11                  Ethiopia  15-49 years   Rate  2020
# 12                   Nigeria  15-49 years   Rate  2020
# 13                      Fiji  15-49 years   Rate  2020
# 14                   Germany  15-49 years   Rate  2020
# 15  United States of America  15-49 years   Rate  2020
# 16                     Kenya  15-49 years   Rate  2020
# 17                     Japan  15-49 years   Rate  2020
# 18                 Australia  15-49 years   Rate  2020
# 19                    Brazil  15-49 years   Rate  2020
# 20                   Romania  15-49 years   Rate  2020
# 21                     Italy  15-49 years   Rate  2020
# 22              Saudi Arabia  15-49 years   Rate  2020
# 23                     China  15-49 years   Rate  2020
# 24                     Egypt  15-49 years   Rate  2020
#
#     COVID Deaths Val (Rate)      upper      lower
# 0                 10.472981  11.087217   9.876074
# 1                 10.159491  20.825411   3.318329
# 2                 57.019696  70.946973  44.181729
# 3                 18.195048  22.069367  14.809403
# 4                 17.427140  18.275500  16.582775
# 5                 67.643147  90.454679  51.068891
# 6                 54.933363  54.955219  54.898359
# 7                 18.638962  25.122020  15.987977
# 8                 11.392234  12.087162  10.701911
# 9                 18.618172  19.671096  17.520649
# 10                 0.239668   0.378687   0.155330
# 11                24.108446  26.069180  22.386505
# 12                18.018582  19.728042  16.611754
# 13                 2.641567   5.517765   0.654506
# 14                 3.468349   3.876612   3.187289
# 15                33.359688  34.663460  32.058489
# 16                42.762396  46.483915  39.448608
# 17                 0.189647   0.211685   0.170640
# 18                 0.231634   0.243760   0.217310
# 19                21.901328  23.845813  20.234796
# 20                18.023526  26.292571  10.591084
# 21                 8.201799   8.677592   7.719720
# 22                17.390042  20.610325  13.677623
# 23                 0.306865   1.600954   0.069869
# 24                26.043847  34.426903  17.968110

# %% [markdown]
# ### 📁 loading the SDI dataset
#
# from the CSV raw file, and making a copy for the cleaned to be dataset
# and preview the first few rows.

# %%
sdi_data = pd.read_csv("../1_datasets/raw_datasets/sdi_by_country_year_2010_2019.csv")

# %%
sdi_2020 = sdi_data.copy()
sdi_2020.head()
# Out:
#   covariate_name_short  location_id                           location_name  \
# 0                  sdi            1                                  Global
# 1                  sdi            4  Southeast Asia, East Asia, and Oceania
# 2                  sdi            5                               East Asia
# 3                  sdi            6                                   China
# 4                  sdi            7   Democratic People's Republic of Korea
#
#    year_id  age_group_id age_group_name  sex_id   sex  mean_value  \
# 0     1950            22       All Ages       3  Both    0.369235
# 1     1950            22       All Ages       3  Both    0.205729
# 2     1950            22       All Ages       3  Both    0.193972
# 3     1950            22       All Ages       3  Both    0.184144
# 4     1950            22       All Ages       3  Both    0.323069
#
#    lower_value  upper_value
# 0     0.369235     0.369235
# 1     0.205729     0.205729
# 2     0.193972     0.193972
# 3     0.184144     0.184144
# 4     0.323069     0.323069

# %% [markdown]
# ### 🎯 Filtering by Country and Year.
#
# To ensure data consistency on relevant entries needed for the merge, we applied filters using the `isin()` method

# %%
year_to_keep = [2020]
sdi_2020 = sdi_2020[
    sdi_2020["location_name"].isin(countries_to_keep)
    & sdi_2020["year_id"].isin(year_to_keep)
]

# %% [markdown]
# ### 🧹 Column Dropping
# - Drop columns not needed for analysis

# %%
sdi_2020 = sdi_2020.drop(
    [
        "covariate_name_short",
        "location_id",
        "age_group_id",
        "age_group_name",
        "sex_id",
        "sex",
        "lower_value",
        "upper_value",
    ],
    axis=1,
    errors="ignore",
)
sdi_2020 = sdi_2020.rename(
    columns={
        "location_name": "Country",
        "year_id": "Year",
        "mean_value": "SDI mean value",
    }
)
sdi_2020.head()
# Out:
#                   Country  Year  SDI mean value
# 51523               China  2020        0.713365
# 51528           Indonesia  2020        0.651927
# 51539                Fiji  2020        0.671431
# 51569             Romania  2020        0.764276
# 51579  Russian Federation  2020        0.806011

# %% [markdown]
# ### ✅ Index Reset & Checking Missing Data
#
# - Resetting the DataFrame index to maintain a clean and sequential index.
# - Count the missing value

# %%
sdi_2020.reset_index(drop=True)
sdi_2020.shape
# Out:
# (25, 3)

# %%
sdi_2020.isnull().sum()
# Out:
# Country           0
# Year              0
# SDI mean value    0
# dtype: int64

# %% [markdown]
# ### 🔗 COVID Deaths and SDI data merge
# Performed an **inner merge** of the covid deaths dataset with the SDI dataset using `"country"` and `"year"` as keys.
# - This enables analysis of the deaths rate in the context of each country's
# socio-demographic development

# %%
merged_covid_sdi = pd.merge(
    df_cleaned_death_data, sdi_2020, on=["Country", "Year"], how="inner"
)
merged_covid_sdi.head()
# Out:
#               Country          age metric  Year  COVID Deaths Val (Rate)  \
# 0               Spain  15-49 years   Rate  2020                10.472981
# 1           Indonesia  15-49 years   Rate  2020                10.159491
# 2              Mexico  15-49 years   Rate  2020                57.019696
# 3  Russian Federation  15-49 years   Rate  2020                18.195048
# 4               Chile  15-49 years   Rate  2020                17.427140
#
#        upper      lower  SDI mean value
# 0  11.087217   9.876074        0.766506
# 1  20.825411   3.318329        0.651927
# 2  70.946973  44.181729        0.660119
# 3  22.069367  14.809403        0.806011
# 4  18.275500  16.582775        0.769214

# %% [markdown]
# Dropping unnecessary columns in the middle merged dataset

# %%
merged_covid_sdi = merged_covid_sdi.drop(
    ["age", "Year", "metric"],
    axis=1,
    errors="ignore",
)
merged_covid_sdi.head()
# Out:
#               Country  COVID Deaths Val (Rate)      upper      lower  \
# 0               Spain                10.472981  11.087217   9.876074
# 1           Indonesia                10.159491  20.825411   3.318329
# 2              Mexico                57.019696  70.946973  44.181729
# 3  Russian Federation                18.195048  22.069367  14.809403
# 4               Chile                17.427140  18.275500  16.582775
#
#    SDI mean value
# 0        0.766506
# 1        0.651927
# 2        0.660119
# 3        0.806011
# 4        0.769214

# %% [markdown]
# ### 🔗 Reading the PM25 Dataset and merge
# reading the pm2.5 dataset and clean it to Perform an **inner merge**  with the covid/SDI dataset

# %%
pm25_concentration = pd.read_csv("../1_datasets/cleaned_datasets/cleaned_pm25_data.csv")
df_pm_average = pm25_concentration.copy()
df_pm_average.copy()
# Out:
#                       Country  Year  PM25 concentration  PM25 lower bound  \
# 0                     Germany  2019               10.73             10.56
# 1                       Japan  2019               10.84             10.02
# 2                      Brazil  2019               10.94              9.37
# 3                       Kenya  2019               12.52              7.80
# 4                     Romania  2019               13.30             12.55
# ..                        ...   ...                 ...               ...
# 245               Afghanistan  2010               68.97             49.48
# 246                      Fiji  2010                7.19              3.79
# 247                    Canada  2010                7.76              7.55
# 248                 Australia  2010                9.03              8.14
# 249  United States of America  2010                9.29              9.14
#
#      PM25 upper bound
# 0               10.93
# 1               11.55
# 2               13.01
# 3               17.78
# 4               14.10
# ..                ...
# 245             96.51
# 246             12.39
# 247              7.96
# 248              9.93
# 249              9.42
#
# [250 rows x 5 columns]

# %% [markdown]
# ### 📌 Averaging PM₂.₅ Concentration (2010–2019)
#
# In this step, we calculate the long-term average of ambient PM₂.₅ concentration for each country between 2010 and 2019. This allows us to capture chronic exposure to air pollution over a decade, which can be compared to COVID-19 outcomes in 2020. We then rename the resulting column to Avg_PM25_2010_2019 for consistency.

# %%
avg_pm25 = df_pm_average.groupby("Country")["PM25 concentration"].mean().reset_index()

# %%
avg_pm25.rename(columns={"PM25 concentration": "Avg_PM25_2010_2019"}, inplace=True)
avg_pm25.head()
# Out:
#        Country  Avg_PM25_2010_2019
# 0  Afghanistan              67.013
# 1    Australia               7.479
# 2   Bangladesh              49.530
# 3       Brazil              13.107
# 4       Canada               7.188

# %% [markdown]
# ### 🔗 Merging COVID-19, SDI, and PM₂.₅ Datasets
#
# In this step, we perform an inner merge to combine all cleaned data sources into a single dataframe, using the common column Country. This includes:
#
# COVID-19 death rates (2020) for the 15–49 age group
#
# Socio-demographic Index (SDI) for the year 2020
#
# Average PM₂.₅ concentration from 2010 to 2019
#
# The resulting dataset is ready for exploratory data analysis (EDA) and modeling to investigate the relationship between long-term air pollution, development level, and COVID-19 outcomes.

# %%
covid_pm25_sdi_final = pd.merge(merged_covid_sdi, avg_pm25, on=["Country"], how="inner")
covid_pm25_sdi_final.head()
# Out:
#               Country  COVID Deaths Val (Rate)      upper      lower  \
# 0               Spain                10.472981  11.087217   9.876074
# 1           Indonesia                10.159491  20.825411   3.318329
# 2              Mexico                57.019696  70.946973  44.181729
# 3  Russian Federation                18.195048  22.069367  14.809403
# 4               Chile                17.427140  18.275500  16.582775
#
#    SDI mean value  Avg_PM25_2010_2019
# 0        0.766506              10.995
# 1        0.651927              19.610
# 2        0.660119              21.268
# 3        0.806011               9.857
# 4        0.769214              22.628

# %% [markdown]
# ### 💾 Export Cleaned Data
#
# Save the cleaned datasets to a `.csv` file for future use:

# %%
df_cleaned_death_data.to_csv("cleaned_death_data_covid.csv", index=False)

# %%
covid_pm25_sdi_final.to_csv("covid_pm25_sdi_final.csv")
